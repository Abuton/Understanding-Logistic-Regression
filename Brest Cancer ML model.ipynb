# %% [markdown]
# ## Import Dependencies

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('max_column', None)

# %% [markdown]
# ##### Read Data

# %%
df = pd.read_csv('data.csv')

df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %% [markdown]
# Lots of informations here but i'll just focus on trying out logistic regression

# %% [markdown]
#  since the target is an object datatype, i chose to encode it. Note That it is not compulsory to encode the target as the algorithm will handle cases like that.

# %%
cols_2_drop = ['id', 'Unnamed: 32']
# drop useless columns from the data
df = df.drop(columns=cols_2_drop, axis=1)
for col in cols_2_drop:
    print(f"{col} has been removed from the data")
# Out:
# id has been removed from the data
# Unnamed: 32 has been removed from the data

# %% [markdown]
# Since the data has been cleaned, modelling is the next thing..

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   diagnosis                569 non-null    object
#  1   radius_mean              569 non-null    float64
#  2   texture_mean             569 non-null    float64
#  3   perimeter_mean           569 non-null    float64
#  4   area_mean                569 non-null    float64
#  5   smoothness_mean          569 non-null    float64
#  6   compactness_mean         569 non-null    float64
#  7   concavity_mean           569 non-null    float64
#  8   concave points_mean      569 non-null    float64
#  9   symmetry_mean            569 non-null    float64
#  10  fractal_dimension_mean   569 non-null    float64
#  11  radius_se                569 non-null    float64
#  12  texture_se               569 non-null    float64
# ...

# %% [markdown]
# Get features and Target

# %%
features = df.iloc[:, 1:]
target = df.iloc[:, 0]

print(f"There are {len(features.columns)} independent features (predictors) to be used to predict cancer diagnosis")
# Out:
# There are 30 independent features (predictors) to be used to predict cancer diagnosis

# %%
# encode the target 'diagnosis'
from sklearn.preprocessing import LabelEncoder
target_encoder = LabelEncoder()

target_encoded = target_encoder.fit_transform(target.values)
print('target encoded')
# Out:
# target encoded

# %% [markdown]
# Splitting the data into train set and test sets

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(features, target_encoded, test_size=.2, random_state=2011)

print(X_test.shape, X_train.shape, y_train.shape, y_test.shape)
# Out:
# (114, 30) (455, 30) (455,) (114,)

# %% [markdown]
# ### Building the ML model
#
# **Logistic Regression**

# %%
# using logistic Regression
from sklearn.linear_model import LogisticRegression
import warnings
warnings.filterwarnings('ignore')

logistic_reg_model = LogisticRegression(max_iter=200)

logistic_reg_model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=200)

# %%
# predict on test set

prediction = logistic_reg_model.predict(X_test)

# %%
# evaluate model
from sklearn import metrics
acc_score = metrics.accuracy_score(y_test, prediction)
f1_score = metrics.f1_score(y_test, prediction)
classification_report = metrics.classification_report(y_test, prediction)
confusion_matrix = metrics.confusion_matrix(y_test, prediction)

# %%
# see results

print(f'Accuracy Score {acc_score}')
print(f'F1 Score {f1_score}')
print(f'Classification Report\n {classification_report}')
print(f'Confusion MatriX\n {confusion_matrix}')
# Out:
# Accuracy Score 0.9473684210526315
# F1 Score 0.9285714285714286
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.97      0.95      0.96        73
#            1       0.91      0.95      0.93        41
#
#     accuracy                           0.95       114
#    macro avg       0.94      0.95      0.94       114
# weighted avg       0.95      0.95      0.95       114
#
# Confusion MatriX
#  [[69  4]
#  [ 2 39]]

# %% [markdown]
# Model result is Amazing. A whooping 95% accuracy and an harmonic mean of 93%.
#
# Now, to reduce model complexity, some of the features will be dropped.
#
# But then which ones?? i am thinking i'll just close eyes and drop any right. That will imply that i did not have 2+ years exp using data and building solution.
#
# So i will use the feature importance.
#
# The question now is what is feature importance??
#
# Feature Importance refers to a class of techniques for assigning scores to input features to a predictive model that indicates the relative importance of each feature when making a prediction. Feature importance can be calculated for regression and classification problems.
#
# These scores are useful because theses scores provides us with
# 1. Better Understanding the data
# 2. Better Understanding of the model
# 3. Reducing number of input features (complexity)

# %%
# calculating feature importance

importance = logistic_reg_model.coef_[0]
feature_names = features.columns.values
fea_imp = pd.DataFrame(zip(feature_names, importance), columns=['Features', 'Importance Score'])

# %%
fea_imp = fea_imp.sort_values(by='Importance Score', ascending=False)

# %% [markdown]
# Let add some Visuals shall we..

# %%
plt.figure(figsize=(18, 9))
plt.bar([feature for feature in range(len(feature_names))], importance)
# Out:
# <BarContainer object of 30 artists>

# %%
fea_imp
# Out:
#                    Features  Importance Score
# 26          concavity_worst          1.169933
# 25        compactness_worst          1.004159
# 6            concavity_mean          0.414201
# 27     concave points_worst          0.339449
# 21            texture_worst          0.332090
# 28           symmetry_worst          0.322287
# 5          compactness_mean          0.317965
# 22          perimeter_worst          0.272953
# 7       concave points_mean          0.176998
# 13                  area_se          0.130202
# 24         smoothness_worst          0.115522
# 29  fractal_dimension_worst          0.104885
# 8             symmetry_mean          0.087588
# 16             concavity_se          0.084268
# 4           smoothness_mean          0.071134
# 15           compactness_se          0.066053
# 18              symmetry_se          0.025675
# 23               area_worst          0.023833
# 9    fractal_dimension_mean          0.023102
# ...

# %% [markdown]
# Given the feature importance, top 10 features will be selected to build the model again and evaluate to see how it performs.
#
# Now this time OOP approach will be employed.
#
# What is OOP? well OOP is an acronym for Object Oriented Programming. In simple terms it is a programming style where every instance is seen as an object that belongs to a class. In a layman's word, i'll say a simple class of Animal that has attributes and method.
#
# Now what is attribute and what is method?
#
# Attributes are what describe a class so for instance class Animal has attributes like mouth, leg, eyes, fins, fur, etc right?
#
# What about Methods? Well Methods are like things that can be performed by a class like actions or behaviours E.g Eating, Meowing, Jumping, Flying, Diving, etc. You get the idea right. Thank you
#
# So in my OOP approach i wont be implementing the class thing but i will be building the rocks by creating methods aka functions
#
# Shall i begin? where is my OOP hollandia..

# %%
get_most_important_features(fea_imp)
# Out:
# The feature names are: ['concavity_worst', 'compactness_worst', 'concavity_mean', 'concave points_worst', 'texture_worst', 'symmetry_worst', 'compactness_mean', 'perimeter_worst', 'concave points_mean', 'area_se']
# ['concavity_worst',
#  'compactness_worst',
#  'concavity_mean',
#  'concave points_worst',
#  'texture_worst',
#  'symmetry_worst',
#  'compactness_mean',
#  'perimeter_worst',
#  'concave points_mean',
#  'area_se']

# %%
# function to select most important features
def get_most_important_features(fea_imp):
    """this function select the most important features based on
       feature importance. returns the top 10 important features
       
       input args: fea_imp -- a dataframe of all the features
       return: 10 features as a list
       """
    features_names = fea_imp['Features'][:10]
#     print(f"The feature names are: {features_names}")
    return list(features_names)

def get_features(df, feature_names, target_name):
    """get features and returns the features data and target data"""
    features = df[feature_names]
    target = df[target_name]
    target = target_encoder.fit_transform(target)
    return features, target

def split_data(features, target):
    """ split the data
    """
    X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=.2, random_state=23)
    return X_train, X_test, y_train, y_test

# function to train the model
def train_model(train, target):
    """ this function builds the model 
    inputs: train : train features
            target : target features
    returns: trained model
    """
    log_model = LogisticRegression(max_iter=200)
    log_model.fit(train, target)
    return log_model

# function to test model
def test_model(model, test_data):
    """this function test the model"""
    prediction = model.predict(test_data)
    return prediction

# function to evaluate model performance
def eval_model(actual, prediction):
    """evaluate the model"""
    acc_score = round(metrics.accuracy_score(actual, prediction), 2)
    f1_score = round(metrics.f1_score(actual, prediction), 2)
    classification_report = metrics.classification_report(actual, prediction)
    confusion_matrix = metrics.confusion_matrix(actual, prediction)
    
    print(f'Accuracy Score {acc_score}')
    print(f'F1 Score {f1_score}')
    print(f'Classification Report\n {classification_report}')
    print(f'Confusion MatriX\n {confusion_matrix}')

# %%
# %%timeit
# using the OOP pipeline
feature_names=get_most_important_features(fea_imp)
# get the data
features, target = get_features(df, feature_names, 'diagnosis')
# split data
X_train, X_test, y_train, y_test = split_data(features, target)
# train model
model = train_model(X_train, y_train)
# test model
pred = test_model(model, X_test)
# evaluate model
eval_model(y_test, pred)
# Out:
# Accuracy Score 0.97
# F1 Score 0.96
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98        75
#            1       0.95      0.97      0.96        39
#
#     accuracy                           0.97       114
#    macro avg       0.97      0.97      0.97       114
# weighted avg       0.97      0.97      0.97       114
#
# Confusion MatriX
#  [[73  2]
#  [ 1 38]]

# %%
# get feature importance
def compute_feature_importance(model):
    """Compute Feature Importance
        input: model trained model
        return dataframe of feature and their score"""
    importance = model.coef_[0]
    feature_names = features.columns.values
    fea_imp = pd.DataFrame(zip(feature_names, importance),
                           columns=['features', 'score']).sort_values(by='score', ascending=False).set_index('features')
    fea_imp.plot(kind='bar', figsize=(13, 6), title='Feature Importance')
    plt.show()
    
    return fea_imp

# %%
feature_imp = compute_feature_importance(model)

# %%
feature_imp
# Out:
#                          score
# features
# concavity_worst       2.239254
# compactness_worst     1.482190
# symmetry_worst        1.140545
# concave points_worst  0.865446
# concavity_mean        0.700664
# compactness_mean      0.400970
# concave points_mean   0.369727
# texture_worst         0.229043
# perimeter_worst       0.140190
# area_se               0.054469
